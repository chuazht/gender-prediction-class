# %% [markdown]
# ## Beforehand...
# ** 1.1 NLTK Setup  **
#    - Install the NLTK library (refer to the previous python file)
#    - Once NLTK is installed, the text data files (corpora) should be downloaded.  See the following cell to start the download.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\tarumt\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\tarumt\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\tarumt\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tarumt\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\tarumt\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\tarumt\anaconda3\lib\site-packages (from click->nltk) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Question 1

# %%
# code to build a classifier to classify names as male or female
# demonstrates the basics of feature extraction and model building
# retrieve dataset inside nltk library

import nltk
nltk.download('names')  #complete this

names = [(name, 'male') for name in nltk.corpus.names.words("male.txt")]       #complete this
names += [(name, 'female') for name in nltk.corpus.names.words("female.txt")]    #complete this
print (names[0:10])

#print (names)
print("\nNumber of male names:")
print (len(nltk.corpus.names.words('male.txt')))

print("\nNumber of female names:")
print (len(nltk.corpus.names.words('female.txt')))

male_names = nltk.corpus.names.words('male.txt')
print("\nFirst 10 male names:")
print (male_names[0:10])

female_names = nltk.corpus.names.words('female.txt')
print("\nFirst 10 female names:")
print (female_names[0:10])
# Out:
# [('Aamir', 'male'), ('Aaron', 'male'), ('Abbey', 'male'), ('Abbie', 'male'), ('Abbot', 'male'), ('Abbott', 'male'), ('Abby', 'male'), ('Abdel', 'male'), ('Abdul', 'male'), ('Abdulkarim', 'male')]
#
# Number of male names:
# 2943
#
# Number of female names:
# 5001
#
# First 10 male names:
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
#
# First 10 female names:
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\TARUMT\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!

# %%
data_path = nltk.data.find('corpora/names')                                         #complete this
print("NLTK data directory:", data_path)
# Out:
# NLTK data directory: C:\Users\TARUMT\AppData\Roaming\nltk_data\corpora\names

# %% [markdown]
# ## Question 2

# %%
 # feature extraction function (since the data is clean, we may skip the data cleaning)

def extract_gender_features(name):
    name = name.lower()
    features = {}
    features["suffix"] = name[-1:]
    features["suffix2"] = name[-2:] if len(name) > 1 else name[0]
    features["suffix3"] = name[-3:] if len(name) > 2 else name[0]
    features["suffix4"] = name[-4:] if len(name) > 3 else name[0]
    features["suffix5"] = name[-5:] if len(name) > 4 else name[0]
    features["suffix6"] = name[-6:] if len(name) > 5 else name[0]
    features["prefix"] = name[:1] #J
    features["prefix2"] = name[:2] if len(name) > 1 else name[0]
    features["prefix3"] = name[:3] if len(name) > 2 else name[0]
    features["prefix4"] = name[:4] if len(name) > 3 else name[0]
    features["prefix5"] = name[:5] if len(name) > 4 else name[0]

    print (features)
    return features

# %% [markdown]
# ## Question 3

# %%
# perform feature extraction for every data

data = [(extract_gender_features(name), gender) for (name, gender) in names]                         #complete this
print (data)  #categarize features with corresponding genders
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Question 4

# %%
# Machine learning: data splitting

import random
random.shuffle(data)                          #complete this

dataCount = len(data)
trainCount = int(.8*dataCount)
print(trainCount)

trainData = data[:trainCount]
testData = data[trainCount:]
print(len(testData))
# Out:
# 6355
# 1589

# %% [markdown]
# ## Question 5

# %%
# Machine learning: data training

bayes = nltk.NaiveBayesClassifier.train(trainData)                           #complete this
print(bayes)
# Out:
# <nltk.classify.naivebayes.NaiveBayesClassifier object at 0x0000028A8E492A60>

# %% [markdown]
# ## Question 6

# %%
# Machine learning: accuracy

print("trainData accuracy=", nltk.classify.accuracy(bayes, trainData))                               #complete this
print("testData accuracy=", nltk.classify.accuracy(bayes, testData))                             #complete this

bayes.show_most_informative_features(25)
# Out:
# trainData accuracy= 0.9411487018095988
# testData accuracy= 0.8376337319068596
# Most Informative Features
#                  suffix2 = 'na'           female : male   =     82.2 : 1.0
#                  suffix2 = 'sa'           female : male   =     33.7 : 1.0
#                  suffix2 = 'ia'           female : male   =     33.6 : 1.0
#                   suffix = 'a'            female : male   =     30.8 : 1.0
#                  suffix2 = 'rd'             male : female =     28.3 : 1.0
#                   suffix = 'k'              male : female =     25.9 : 1.0
#                  suffix2 = 'us'             male : female =     25.8 : 1.0
#                  suffix2 = 'io'             male : female =     24.2 : 1.0
#                  suffix3 = 'tta'          female : male   =     22.3 : 1.0
#                  suffix2 = 'ra'           female : male   =     21.9 : 1.0
#                  suffix3 = 'ana'          female : male   =     21.4 : 1.0
#                  suffix2 = 'ta'           female : male   =     21.1 : 1.0
#                  suffix2 = 'ld'             male : female =     20.6 : 1.0
#                  suffix4 = 'etta'         female : male   =     20.5 : 1.0
#                  suffix4 = 'bert'           male : female =     18.8 : 1.0
#                  suffix2 = 'rt'             male : female =     18.1 : 1.0
#                  suffix4 = 'anne'         female : male   =     17.7 : 1.0
#                  suffix3 = 'ard'            male : female =     17.3 : 1.0
#                  suffix2 = 'os'             male : female =     16.3 : 1.0
#                  suffix3 = 'nne'          female : male   =     15.6 : 1.0
#                   suffix = 'f'              male : female =     14.8 : 1.0
#                  prefix2 = 'hu'             male : female =     14.1 : 1.0
#                  suffix3 = 'old'            male : female =     13.1 : 1.0
#                  suffix3 = 'ita'          female : male   =     12.9 : 1.0
#                  suffix2 = 'lo'             male : female =     12.5 : 1.0

# %% [markdown]
# ## Question 7

# %%
# Predict a new name

input_name = input("Name:")
print(bayes.classify(extract_gender_features(input_name)))                                    #complete this
# Out:
# Name:chua zhong hui
# {'suffix': 'i', 'suffix2': 'ui', 'suffix3': 'hui', 'suffix4': ' hui', 'suffix5': 'g hui', 'suffix6': 'ng hui', 'prefix': 'c', 'prefix2': 'ch', 'prefix3': 'chu', 'prefix4': 'chua', 'prefix5': 'chua '}
# male

# %% [markdown]
# ## Question 8

# %%
# Display wrong prediction for improvement

errors = []

for (name,label) in names:
    if bayes.classify(extract_gender_features(name)) != label:
        errors.append({"name": name, "label": label})
# 
errors
# Out:
# {'suffix': 'r', 'suffix2': 'ir', 'suffix3': 'mir', 'suffix4': 'amir', 'suffix5': 'aamir', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'aa', 'prefix3': 'aam', 'prefix4': 'aami', 'prefix5': 'aamir'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ron', 'suffix4': 'aron', 'suffix5': 'aaron', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'aa', 'prefix3': 'aar', 'prefix4': 'aaro', 'prefix5': 'aaron'}
# {'suffix': 'y', 'suffix2': 'ey', 'suffix3': 'bey', 'suffix4': 'bbey', 'suffix5': 'abbey', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abb', 'prefix4': 'abbe', 'prefix5': 'abbey'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'bie', 'suffix4': 'bbie', 'suffix5': 'abbie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abb', 'prefix4': 'abbi', 'prefix5': 'abbie'}
# {'suffix': 't', 'suffix2': 'ot', 'suffix3': 'bot', 'suffix4': 'bbot', 'suffix5': 'abbot', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abb', 'prefix4': 'abbo', 'prefix5': 'abbot'}
# {'suffix': 't', 'suffix2': 'tt', 'suffix3': 'ott', 'suffix4': 'bott', 'suffix5': 'bbott', 'suffix6': 'abbott', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abb', 'prefix4': 'abbo', 'prefix5': 'abbot'}
# {'suffix': 'y', 'suffix2': 'by', 'suffix3': 'bby', 'suffix4': 'abby', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abb', 'prefix4': 'abby', 'prefix5': 'a'}
# {'suffix': 'l', 'suffix2': 'el', 'suffix3': 'del', 'suffix4': 'bdel', 'suffix5': 'abdel', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abd', 'prefix4': 'abde', 'prefix5': 'abdel'}
# {'suffix': 'l', 'suffix2': 'ul', 'suffix3': 'dul', 'suffix4': 'bdul', 'suffix5': 'abdul', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abd', 'prefix4': 'abdu', 'prefix5': 'abdul'}
# {'suffix': 'm', 'suffix2': 'im', 'suffix3': 'rim', 'suffix4': 'arim', 'suffix5': 'karim', 'suffix6': 'lkarim', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abd', 'prefix4': 'abdu', 'prefix5': 'abdul'}
# {'suffix': 'h', 'suffix2': 'ah', 'suffix3': 'lah', 'suffix4': 'llah', 'suffix5': 'ullah', 'suffix6': 'dullah', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abd', 'prefix4': 'abdu', 'prefix5': 'abdul'}
# {'suffix': 'e', 'suffix2': 'be', 'suffix3': 'abe', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abe', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'l', 'suffix2': 'el', 'suffix3': 'bel', 'suffix4': 'abel', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abe', 'prefix4': 'abel', 'prefix5': 'a'}
# {'suffix': 'd', 'suffix2': 'rd', 'suffix3': 'ard', 'suffix4': 'lard', 'suffix5': 'elard', 'suffix6': 'belard', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abe', 'prefix4': 'abel', 'prefix5': 'abela'}
# {'suffix': 'r', 'suffix2': 'er', 'suffix3': 'ner', 'suffix4': 'bner', 'suffix5': 'abner', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abn', 'prefix4': 'abne', 'prefix5': 'abner'}
# {'suffix': 'm', 'suffix2': 'am', 'suffix3': 'ham', 'suffix4': 'aham', 'suffix5': 'raham', 'suffix6': 'braham', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abr', 'prefix4': 'abra', 'prefix5': 'abrah'}
# {'suffix': 'm', 'suffix2': 'am', 'suffix3': 'ram', 'suffix4': 'bram', 'suffix5': 'abram', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ab', 'prefix3': 'abr', 'prefix4': 'abra', 'prefix5': 'abram'}
# {'suffix': 'e', 'suffix2': 'ce', 'suffix3': 'ace', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ac', 'prefix3': 'ace', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'r', 'suffix2': 'ir', 'suffix3': 'air', 'suffix4': 'dair', 'suffix5': 'adair', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ada', 'prefix4': 'adai', 'prefix5': 'adair'}
# {'suffix': 'm', 'suffix2': 'am', 'suffix3': 'dam', 'suffix4': 'adam', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ada', 'prefix4': 'adam', 'prefix5': 'a'}
# {'suffix': 's', 'suffix2': 'ms', 'suffix3': 'ams', 'suffix4': 'dams', 'suffix5': 'adams', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ada', 'prefix4': 'adam', 'prefix5': 'adams'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'die', 'suffix4': 'ddie', 'suffix5': 'addie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'add', 'prefix4': 'addi', 'prefix5': 'addie'}
# {'suffix': 'r', 'suffix2': 'er', 'suffix3': 'ger', 'suffix4': 'dger', 'suffix5': 'adger', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'adg', 'prefix4': 'adge', 'prefix5': 'adger'}
# {'suffix': 'a', 'suffix2': 'ya', 'suffix3': 'tya', 'suffix4': 'itya', 'suffix5': 'ditya', 'suffix6': 'aditya', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'adi', 'prefix4': 'adit', 'prefix5': 'adity'}
# {'suffix': 'i', 'suffix2': 'ai', 'suffix3': 'lai', 'suffix4': 'dlai', 'suffix5': 'adlai', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'adl', 'prefix4': 'adla', 'prefix5': 'adlai'}
# {'suffix': 'n', 'suffix2': 'an', 'suffix3': 'nan', 'suffix4': 'dnan', 'suffix5': 'adnan', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'adn', 'prefix4': 'adna', 'prefix5': 'adnan'}
# {'suffix': 'f', 'suffix2': 'lf', 'suffix3': 'olf', 'suffix4': 'dolf', 'suffix5': 'adolf', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ado', 'prefix4': 'adol', 'prefix5': 'adolf'}
# {'suffix': 'o', 'suffix2': 'fo', 'suffix3': 'lfo', 'suffix4': 'olfo', 'suffix5': 'dolfo', 'suffix6': 'adolfo', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ado', 'prefix4': 'adol', 'prefix5': 'adolf'}
# {'suffix': 'h', 'suffix2': 'ph', 'suffix3': 'lph', 'suffix4': 'olph', 'suffix5': 'dolph', 'suffix6': 'adolph', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ado', 'prefix4': 'adol', 'prefix5': 'adolp'}
# {'suffix': 'e', 'suffix2': 'he', 'suffix3': 'phe', 'suffix4': 'lphe', 'suffix5': 'olphe', 'suffix6': 'dolphe', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ado', 'prefix4': 'adol', 'prefix5': 'adolp'}
# {'suffix': 'o', 'suffix2': 'ho', 'suffix3': 'pho', 'suffix4': 'lpho', 'suffix5': 'olpho', 'suffix6': 'dolpho', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ado', 'prefix4': 'adol', 'prefix5': 'adolp'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'hus', 'suffix4': 'phus', 'suffix5': 'lphus', 'suffix6': 'olphus', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'ado', 'prefix4': 'adol', 'prefix5': 'adolp'}
# {'suffix': 'n', 'suffix2': 'an', 'suffix3': 'ian', 'suffix4': 'rian', 'suffix5': 'drian', 'suffix6': 'adrian', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'adr', 'prefix4': 'adri', 'prefix5': 'adria'}
# {'suffix': 'k', 'suffix2': 'ck', 'suffix3': 'ick', 'suffix4': 'rick', 'suffix5': 'drick', 'suffix6': 'adrick', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'adr', 'prefix4': 'adri', 'prefix5': 'adric'}
# {'suffix': 'n', 'suffix2': 'en', 'suffix3': 'ien', 'suffix4': 'rien', 'suffix5': 'drien', 'suffix6': 'adrien', 'prefix': 'a', 'prefix2': 'ad', 'prefix3': 'adr', 'prefix4': 'adri', 'prefix5': 'adrie'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'non', 'suffix4': 'mnon', 'suffix5': 'emnon', 'suffix6': 'memnon', 'prefix': 'a', 'prefix2': 'ag', 'prefix3': 'aga', 'prefix4': 'agam', 'prefix5': 'agame'}
# {'suffix': 'o', 'suffix2': 'do', 'suffix3': 'ldo', 'suffix4': 'aldo', 'suffix5': 'naldo', 'suffix6': 'inaldo', 'prefix': 'a', 'prefix2': 'ag', 'prefix3': 'agu', 'prefix4': 'agui', 'prefix5': 'aguin'}
# {'suffix': 'e', 'suffix2': 'te', 'suffix3': 'ste', 'suffix4': 'uste', 'suffix5': 'guste', 'suffix6': 'aguste', 'prefix': 'a', 'prefix2': 'ag', 'prefix3': 'agu', 'prefix4': 'agus', 'prefix5': 'agust'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'tin', 'suffix4': 'stin', 'suffix5': 'ustin', 'suffix6': 'gustin', 'prefix': 'a', 'prefix2': 'ag', 'prefix3': 'agu', 'prefix4': 'agus', 'prefix5': 'agust'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ron', 'suffix4': 'aron', 'suffix5': 'haron', 'suffix6': 'aharon', 'prefix': 'a', 'prefix2': 'ah', 'prefix3': 'aha', 'prefix4': 'ahar', 'prefix5': 'aharo'}
# {'suffix': 'd', 'suffix2': 'ad', 'suffix3': 'mad', 'suffix4': 'hmad', 'suffix5': 'ahmad', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ah', 'prefix3': 'ahm', 'prefix4': 'ahma', 'prefix5': 'ahmad'}
# {'suffix': 'd', 'suffix2': 'ed', 'suffix3': 'med', 'suffix4': 'hmed', 'suffix5': 'ahmed', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ah', 'prefix3': 'ahm', 'prefix4': 'ahme', 'prefix5': 'ahmed'}
# {'suffix': 't', 'suffix2': 'et', 'suffix3': 'met', 'suffix4': 'hmet', 'suffix5': 'ahmet', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ah', 'prefix3': 'ahm', 'prefix4': 'ahme', 'prefix5': 'ahmet'}
# {'suffix': 'i', 'suffix2': 'ai', 'suffix3': 'jai', 'suffix4': 'ajai', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'aj', 'prefix3': 'aja', 'prefix4': 'ajai', 'prefix5': 'a'}
# {'suffix': 'y', 'suffix2': 'ay', 'suffix3': 'jay', 'suffix4': 'ajay', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'aj', 'prefix3': 'aja', 'prefix4': 'ajay', 'prefix5': 'a'}
# {'suffix': 'l', 'suffix2': 'al', 'suffix3': 'a', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'a', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'a', 'suffix2': 'aa', 'suffix3': 'laa', 'suffix4': 'alaa', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ala', 'prefix4': 'alaa', 'prefix5': 'a'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'ain', 'suffix4': 'lain', 'suffix5': 'alain', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ala', 'prefix4': 'alai', 'prefix5': 'alain'}
# {'suffix': 'n', 'suffix2': 'an', 'suffix3': 'lan', 'suffix4': 'alan', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ala', 'prefix4': 'alan', 'prefix5': 'a'}
# {'suffix': 'r', 'suffix2': 'ir', 'suffix3': 'air', 'suffix4': 'dair', 'suffix5': 'sdair', 'suffix6': 'asdair', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ala', 'prefix4': 'alas', 'prefix5': 'alasd'}
# {'suffix': 'r', 'suffix2': 'ir', 'suffix3': 'air', 'suffix4': 'tair', 'suffix5': 'stair', 'suffix6': 'astair', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ala', 'prefix4': 'alas', 'prefix5': 'alast'}
# {'suffix': 's', 'suffix2': 'os', 'suffix3': 'ros', 'suffix4': 'tros', 'suffix5': 'atros', 'suffix6': 'batros', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alb', 'prefix4': 'alba', 'prefix5': 'albat'}
# {'suffix': 't', 'suffix2': 'rt', 'suffix3': 'ert', 'suffix4': 'bert', 'suffix5': 'lbert', 'suffix6': 'albert', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alb', 'prefix4': 'albe', 'prefix5': 'alber'}
# {'suffix': 'o', 'suffix2': 'to', 'suffix3': 'rto', 'suffix4': 'erto', 'suffix5': 'berto', 'suffix6': 'lberto', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alb', 'prefix4': 'albe', 'prefix5': 'alber'}
# {'suffix': 't', 'suffix2': 'ht', 'suffix3': 'cht', 'suffix4': 'echt', 'suffix5': 'recht', 'suffix6': 'brecht', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alb', 'prefix4': 'albr', 'prefix5': 'albre'}
# {'suffix': 'n', 'suffix2': 'en', 'suffix3': 'den', 'suffix4': 'lden', 'suffix5': 'alden', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ald', 'prefix4': 'alde', 'prefix5': 'alden'}
# {'suffix': 's', 'suffix2': 'is', 'suffix3': 'dis', 'suffix4': 'ldis', 'suffix5': 'aldis', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ald', 'prefix4': 'aldi', 'prefix5': 'aldis'}
# {'suffix': 'o', 'suffix2': 'do', 'suffix3': 'ldo', 'suffix4': 'aldo', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ald', 'prefix4': 'aldo', 'prefix5': 'a'}
# {'suffix': 'c', 'suffix2': 'ic', 'suffix3': 'ric', 'suffix4': 'dric', 'suffix5': 'ldric', 'suffix6': 'aldric', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ald', 'prefix4': 'aldr', 'prefix5': 'aldri'}
# {'suffix': 'h', 'suffix2': 'ch', 'suffix3': 'ich', 'suffix4': 'rich', 'suffix5': 'drich', 'suffix6': 'ldrich', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ald', 'prefix4': 'aldr', 'prefix5': 'aldri'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'dus', 'suffix4': 'ldus', 'suffix5': 'aldus', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ald', 'prefix4': 'aldu', 'prefix5': 'aldus'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'win', 'suffix4': 'dwin', 'suffix5': 'ldwin', 'suffix6': 'aldwin', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ald', 'prefix4': 'aldw', 'prefix5': 'aldwi'}
# {'suffix': 'c', 'suffix2': 'ec', 'suffix3': 'lec', 'suffix4': 'alec', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alec', 'prefix5': 'a'}
# {'suffix': 'k', 'suffix2': 'ck', 'suffix3': 'eck', 'suffix4': 'leck', 'suffix5': 'aleck', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alec', 'prefix5': 'aleck'}
# {'suffix': 'o', 'suffix2': 'ro', 'suffix3': 'dro', 'suffix4': 'ndro', 'suffix5': 'andro', 'suffix6': 'jandro', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alej', 'prefix5': 'aleja'}
# {'suffix': 's', 'suffix2': 'ks', 'suffix3': 'eks', 'suffix4': 'leks', 'suffix5': 'aleks', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alek', 'prefix5': 'aleks'}
# {'suffix': 's', 'suffix2': 'rs', 'suffix3': 'drs', 'suffix4': 'ndrs', 'suffix5': 'andrs', 'suffix6': 'sandrs', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alek', 'prefix5': 'aleks'}
# {'suffix': 'o', 'suffix2': 'ro', 'suffix3': 'dro', 'suffix4': 'ndro', 'suffix5': 'andro', 'suffix6': 'sandro', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'ales', 'prefix5': 'aless'}
# {'suffix': 'x', 'suffix2': 'ex', 'suffix3': 'lex', 'suffix4': 'alex', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alex', 'prefix5': 'a'}
# {'suffix': 'r', 'suffix2': 'er', 'suffix3': 'der', 'suffix4': 'nder', 'suffix5': 'ander', 'suffix6': 'xander', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alex', 'prefix5': 'alexa'}
# {'suffix': 'i', 'suffix2': 'ei', 'suffix3': 'xei', 'suffix4': 'exei', 'suffix5': 'lexei', 'suffix6': 'alexei', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alex', 'prefix5': 'alexe'}
# {'suffix': 's', 'suffix2': 'is', 'suffix3': 'xis', 'suffix4': 'exis', 'suffix5': 'lexis', 'suffix6': 'alexis', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ale', 'prefix4': 'alex', 'prefix5': 'alexi'}
# {'suffix': 'f', 'suffix2': 'lf', 'suffix3': 'alf', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'fie', 'suffix4': 'lfie', 'suffix5': 'alfie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'alfi', 'prefix5': 'alfie'}
# {'suffix': 'e', 'suffix2': 'se', 'suffix3': 'nse', 'suffix4': 'onse', 'suffix5': 'fonse', 'suffix6': 'lfonse', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'alfo', 'prefix5': 'alfon'}
# {'suffix': 'o', 'suffix2': 'so', 'suffix3': 'nso', 'suffix4': 'onso', 'suffix5': 'fonso', 'suffix6': 'lfonso', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'alfo', 'prefix5': 'alfon'}
# {'suffix': 'o', 'suffix2': 'zo', 'suffix3': 'nzo', 'suffix4': 'onzo', 'suffix5': 'fonzo', 'suffix6': 'lfonzo', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'alfo', 'prefix5': 'alfon'}
# {'suffix': 'd', 'suffix2': 'rd', 'suffix3': 'ord', 'suffix4': 'ford', 'suffix5': 'lford', 'suffix6': 'alford', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'alfo', 'prefix5': 'alfor'}
# {'suffix': 'd', 'suffix2': 'ed', 'suffix3': 'red', 'suffix4': 'fred', 'suffix5': 'lfred', 'suffix6': 'alfred', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'alfr', 'prefix5': 'alfre'}
# {'suffix': 'o', 'suffix2': 'do', 'suffix3': 'edo', 'suffix4': 'redo', 'suffix5': 'fredo', 'suffix6': 'lfredo', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alf', 'prefix4': 'alfr', 'prefix5': 'alfre'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'non', 'suffix4': 'rnon', 'suffix5': 'ernon', 'suffix6': 'gernon', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alg', 'prefix4': 'alge', 'prefix5': 'alger'}
# {'suffix': 'i', 'suffix2': 'li', 'suffix3': 'ali', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ali', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'c', 'suffix2': 'ic', 'suffix3': 'lic', 'suffix4': 'alic', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ali', 'prefix4': 'alic', 'prefix5': 'a'}
# {'suffix': 'r', 'suffix2': 'er', 'suffix3': 'ter', 'suffix4': 'ster', 'suffix5': 'ister', 'suffix6': 'lister', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ali', 'prefix4': 'alis', 'prefix5': 'alist'}
# {'suffix': 'x', 'suffix2': 'ix', 'suffix3': 'lix', 'suffix4': 'alix', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'ali', 'prefix4': 'alix', 'prefix5': 'a'}
# {'suffix': 'h', 'suffix2': 'ah', 'suffix3': 'lah', 'suffix4': 'llah', 'suffix5': 'allah', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'all', 'prefix4': 'alla', 'prefix5': 'allah'}
# {'suffix': 'n', 'suffix2': 'an', 'suffix3': 'lan', 'suffix4': 'llan', 'suffix5': 'allan', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'all', 'prefix4': 'alla', 'prefix5': 'allan'}
# {'suffix': 'n', 'suffix2': 'en', 'suffix3': 'len', 'suffix4': 'llen', 'suffix5': 'allen', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'all', 'prefix4': 'alle', 'prefix5': 'allen'}
# {'suffix': 'y', 'suffix2': 'ey', 'suffix3': 'ley', 'suffix4': 'lley', 'suffix5': 'alley', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'all', 'prefix4': 'alle', 'prefix5': 'alley'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'lie', 'suffix4': 'llie', 'suffix5': 'allie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'all', 'prefix4': 'alli', 'prefix5': 'allie'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'lin', 'suffix4': 'llin', 'suffix5': 'allin', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'all', 'prefix4': 'alli', 'prefix5': 'allin'}
# {'suffix': 'n', 'suffix2': 'yn', 'suffix3': 'lyn', 'suffix4': 'llyn', 'suffix5': 'allyn', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'all', 'prefix4': 'ally', 'prefix5': 'allyn'}
# {'suffix': 'o', 'suffix2': 'so', 'suffix3': 'nso', 'suffix4': 'onso', 'suffix5': 'lonso', 'suffix6': 'alonso', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alo', 'prefix4': 'alon', 'prefix5': 'alons'}
# {'suffix': 'o', 'suffix2': 'zo', 'suffix3': 'nzo', 'suffix4': 'onzo', 'suffix5': 'lonzo', 'suffix6': 'alonzo', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alo', 'prefix4': 'alon', 'prefix5': 'alonz'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'ius', 'suffix4': 'sius', 'suffix5': 'ysius', 'suffix6': 'oysius', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alo', 'prefix4': 'aloy', 'prefix5': 'aloys'}
# {'suffix': 'e', 'suffix2': 'se', 'suffix3': 'nse', 'suffix4': 'onse', 'suffix5': 'honse', 'suffix6': 'phonse', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alp', 'prefix4': 'alph', 'prefix5': 'alpho'}
# {'suffix': 'o', 'suffix2': 'so', 'suffix3': 'nso', 'suffix4': 'onso', 'suffix5': 'honso', 'suffix6': 'phonso', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alp', 'prefix4': 'alph', 'prefix5': 'alpho'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ton', 'suffix4': 'ston', 'suffix5': 'lston', 'suffix6': 'alston', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'als', 'prefix4': 'alst', 'prefix5': 'alsto'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ton', 'suffix4': 'lton', 'suffix5': 'alton', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alt', 'prefix4': 'alto', 'prefix5': 'alton'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'vin', 'suffix4': 'lvin', 'suffix5': 'alvin', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alv', 'prefix4': 'alvi', 'prefix5': 'alvin'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'win', 'suffix4': 'lwin', 'suffix5': 'alwin', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'al', 'prefix3': 'alw', 'prefix4': 'alwi', 'prefix5': 'alwin'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'eus', 'suffix4': 'deus', 'suffix5': 'adeus', 'suffix6': 'madeus', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'ama', 'prefix4': 'amad', 'prefix5': 'amade'}
# {'suffix': 's', 'suffix2': 'os', 'suffix3': 'ros', 'suffix4': 'bros', 'suffix5': 'mbros', 'suffix6': 'ambros', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'amb', 'prefix4': 'ambr', 'prefix5': 'ambro'}
# {'suffix': 'e', 'suffix2': 'se', 'suffix3': 'ose', 'suffix4': 'rose', 'suffix5': 'brose', 'suffix6': 'mbrose', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'amb', 'prefix4': 'ambr', 'prefix5': 'ambro'}
# {'suffix': 'i', 'suffix2': 'si', 'suffix3': 'osi', 'suffix4': 'rosi', 'suffix5': 'brosi', 'suffix6': 'mbrosi', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'amb', 'prefix4': 'ambr', 'prefix5': 'ambro'}
# {'suffix': 'o', 'suffix2': 'io', 'suffix3': 'sio', 'suffix4': 'osio', 'suffix5': 'rosio', 'suffix6': 'brosio', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'amb', 'prefix4': 'ambr', 'prefix5': 'ambro'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'ius', 'suffix4': 'sius', 'suffix5': 'osius', 'suffix6': 'rosius', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'amb', 'prefix4': 'ambr', 'prefix5': 'ambro'}
# {'suffix': 'y', 'suffix2': 'ry', 'suffix3': 'ery', 'suffix4': 'mery', 'suffix5': 'amery', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'ame', 'prefix4': 'amer', 'prefix5': 'amery'}
# {'suffix': 'y', 'suffix2': 'ry', 'suffix3': 'ory', 'suffix4': 'mory', 'suffix5': 'amory', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'amo', 'prefix4': 'amor', 'prefix5': 'amory'}
# {'suffix': 's', 'suffix2': 'os', 'suffix3': 'mos', 'suffix4': 'amos', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'am', 'prefix3': 'amo', 'prefix4': 'amos', 'prefix5': 'a'}
# {'suffix': 'l', 'suffix2': 'ol', 'suffix3': 'tol', 'suffix4': 'atol', 'suffix5': 'natol', 'suffix6': 'anatol', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ana', 'prefix4': 'anat', 'prefix5': 'anato'}
# {'suffix': 'e', 'suffix2': 'le', 'suffix3': 'ole', 'suffix4': 'tole', 'suffix5': 'atole', 'suffix6': 'natole', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ana', 'prefix4': 'anat', 'prefix5': 'anato'}
# {'suffix': 'o', 'suffix2': 'lo', 'suffix3': 'llo', 'suffix4': 'ollo', 'suffix5': 'tollo', 'suffix6': 'atollo', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ana', 'prefix4': 'anat', 'prefix5': 'anato'}
# {'suffix': 'y', 'suffix2': 'ly', 'suffix3': 'oly', 'suffix4': 'toly', 'suffix5': 'atoly', 'suffix6': 'natoly', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ana', 'prefix4': 'anat', 'prefix5': 'anato'}
# {'suffix': 's', 'suffix2': 'rs', 'suffix3': 'ers', 'suffix4': 'ders', 'suffix5': 'nders', 'suffix6': 'anders', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'ande', 'prefix5': 'ander'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'die', 'suffix4': 'ndie', 'suffix5': 'andie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andi', 'prefix5': 'andie'}
# {'suffix': 's', 'suffix2': 'is', 'suffix3': 'nis', 'suffix4': 'onis', 'suffix5': 'donis', 'suffix6': 'ndonis', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'ando', 'prefix5': 'andon'}
# {'suffix': 'e', 'suffix2': 're', 'suffix3': 'dre', 'suffix4': 'ndre', 'suffix5': 'andre', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andre'}
# {'suffix': 'a', 'suffix2': 'ea', 'suffix3': 'rea', 'suffix4': 'drea', 'suffix5': 'ndrea', 'suffix6': 'andrea', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andre'}
# {'suffix': 's', 'suffix2': 'as', 'suffix3': 'eas', 'suffix4': 'reas', 'suffix5': 'dreas', 'suffix6': 'ndreas', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andre'}
# {'suffix': 'j', 'suffix2': 'ej', 'suffix3': 'rej', 'suffix4': 'drej', 'suffix5': 'ndrej', 'suffix6': 'andrej', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andre'}
# {'suffix': 's', 'suffix2': 'es', 'suffix3': 'res', 'suffix4': 'dres', 'suffix5': 'ndres', 'suffix6': 'andres', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andre'}
# {'suffix': 'w', 'suffix2': 'ew', 'suffix3': 'rew', 'suffix4': 'drew', 'suffix5': 'ndrew', 'suffix6': 'andrew', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andre'}
# {'suffix': 'y', 'suffix2': 'ey', 'suffix3': 'rey', 'suffix4': 'drey', 'suffix5': 'ndrey', 'suffix6': 'andrey', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andre'}
# {'suffix': 'i', 'suffix2': 'ri', 'suffix3': 'dri', 'suffix4': 'ndri', 'suffix5': 'andri', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andri'}
# {'suffix': 's', 'suffix2': 'os', 'suffix3': 'ros', 'suffix4': 'dros', 'suffix5': 'ndros', 'suffix6': 'andros', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andro'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'rus', 'suffix4': 'drus', 'suffix5': 'ndrus', 'suffix6': 'andrus', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andru'}
# {'suffix': 'j', 'suffix2': 'ej', 'suffix3': 'zej', 'suffix4': 'rzej', 'suffix5': 'drzej', 'suffix6': 'ndrzej', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andr', 'prefix5': 'andrz'}
# {'suffix': 'y', 'suffix2': 'dy', 'suffix3': 'ndy', 'suffix4': 'andy', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'and', 'prefix4': 'andy', 'prefix5': 'a'}
# {'suffix': 'l', 'suffix2': 'el', 'suffix3': 'gel', 'suffix4': 'ngel', 'suffix5': 'angel', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ang', 'prefix4': 'ange', 'prefix5': 'angel'}
# {'suffix': 'o', 'suffix2': 'co', 'suffix3': 'ico', 'suffix4': 'lico', 'suffix5': 'elico', 'suffix6': 'gelico', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ang', 'prefix4': 'ange', 'prefix5': 'angel'}
# {'suffix': 'o', 'suffix2': 'lo', 'suffix3': 'elo', 'suffix4': 'gelo', 'suffix5': 'ngelo', 'suffix6': 'angelo', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ang', 'prefix4': 'ange', 'prefix5': 'angel'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'gie', 'suffix4': 'ngie', 'suffix5': 'angie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ang', 'prefix4': 'angi', 'prefix5': 'angie'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'gus', 'suffix4': 'ngus', 'suffix5': 'angus', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ang', 'prefix4': 'angu', 'prefix5': 'angus'}
# {'suffix': 'l', 'suffix2': 'el', 'suffix3': 'sel', 'suffix4': 'nsel', 'suffix5': 'ansel', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ans', 'prefix4': 'anse', 'prefix5': 'ansel'}
# {'suffix': 'l', 'suffix2': 'll', 'suffix3': 'ell', 'suffix4': 'sell', 'suffix5': 'nsell', 'suffix6': 'ansell', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ans', 'prefix4': 'anse', 'prefix5': 'ansel'}
# {'suffix': 'm', 'suffix2': 'lm', 'suffix3': 'elm', 'suffix4': 'selm', 'suffix5': 'nselm', 'suffix6': 'anselm', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ans', 'prefix4': 'anse', 'prefix5': 'ansel'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'son', 'suffix4': 'nson', 'suffix5': 'anson', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ans', 'prefix4': 'anso', 'prefix5': 'anson'}
# {'suffix': 'y', 'suffix2': 'ny', 'suffix3': 'ony', 'suffix4': 'hony', 'suffix5': 'thony', 'suffix6': 'nthony', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anth', 'prefix5': 'antho'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'tin', 'suffix4': 'ntin', 'suffix5': 'antin', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anti', 'prefix5': 'antin'}
# {'suffix': 'e', 'suffix2': 'ne', 'suffix3': 'ine', 'suffix4': 'oine', 'suffix5': 'toine', 'suffix6': 'ntoine', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'antoi'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ton', 'suffix4': 'nton', 'suffix5': 'anton', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 'e', 'suffix2': 'ne', 'suffix3': 'one', 'suffix4': 'tone', 'suffix5': 'ntone', 'suffix6': 'antone', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 'i', 'suffix2': 'ni', 'suffix3': 'oni', 'suffix4': 'toni', 'suffix5': 'ntoni', 'suffix6': 'antoni', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'nin', 'suffix4': 'onin', 'suffix5': 'tonin', 'suffix6': 'ntonin', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 'o', 'suffix2': 'no', 'suffix3': 'ino', 'suffix4': 'nino', 'suffix5': 'onino', 'suffix6': 'tonino', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 'o', 'suffix2': 'io', 'suffix3': 'nio', 'suffix4': 'onio', 'suffix5': 'tonio', 'suffix6': 'ntonio', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'ius', 'suffix4': 'nius', 'suffix5': 'onius', 'suffix6': 'tonius', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 'y', 'suffix2': 'ny', 'suffix3': 'ony', 'suffix4': 'tony', 'suffix5': 'ntony', 'suffix6': 'antony', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'ant', 'prefix4': 'anto', 'prefix5': 'anton'}
# {'suffix': 'g', 'suffix2': 'ag', 'suffix3': 'rag', 'suffix4': 'urag', 'suffix5': 'nurag', 'suffix6': 'anurag', 'prefix': 'a', 'prefix2': 'an', 'prefix3': 'anu', 'prefix4': 'anur', 'prefix5': 'anura'}
# {'suffix': 'o', 'suffix2': 'lo', 'suffix3': 'llo', 'suffix4': 'ollo', 'suffix5': 'pollo', 'suffix6': 'apollo', 'prefix': 'a', 'prefix2': 'ap', 'prefix3': 'apo', 'prefix4': 'apol', 'prefix5': 'apoll'}
# {'suffix': 's', 'suffix2': 'os', 'suffix3': 'los', 'suffix4': 'olos', 'suffix5': 'tolos', 'suffix6': 'stolos', 'prefix': 'a', 'prefix2': 'ap', 'prefix3': 'apo', 'prefix4': 'apos', 'prefix5': 'apost'}
# {'suffix': 'm', 'suffix2': 'am', 'suffix3': 'ram', 'suffix4': 'aram', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'ara', 'prefix4': 'aram', 'prefix5': 'a'}
# {'suffix': 'd', 'suffix2': 'ld', 'suffix3': 'ald', 'suffix4': 'bald', 'suffix5': 'ibald', 'suffix6': 'hibald', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arc', 'prefix4': 'arch', 'prefix5': 'archi'}
# {'suffix': 'd', 'suffix2': 'ld', 'suffix3': 'old', 'suffix4': 'bold', 'suffix5': 'ibold', 'suffix6': 'hibold', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arc', 'prefix4': 'arch', 'prefix5': 'archi'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'hie', 'suffix4': 'chie', 'suffix5': 'rchie', 'suffix6': 'archie', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arc', 'prefix4': 'arch', 'prefix5': 'archi'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'hon', 'suffix4': 'chon', 'suffix5': 'rchon', 'suffix6': 'archon', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arc', 'prefix4': 'arch', 'prefix5': 'archo'}
# {'suffix': 'y', 'suffix2': 'hy', 'suffix3': 'chy', 'suffix4': 'rchy', 'suffix5': 'archy', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arc', 'prefix4': 'arch', 'prefix5': 'archy'}
# {'suffix': 'l', 'suffix2': 'el', 'suffix3': 'rel', 'suffix4': 'arel', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'are', 'prefix4': 'arel', 'prefix5': 'a'}
# {'suffix': 'i', 'suffix2': 'ri', 'suffix3': 'ari', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'ari', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'rie', 'suffix4': 'arie', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'ari', 'prefix4': 'arie', 'prefix5': 'a'}
# {'suffix': 'l', 'suffix2': 'el', 'suffix3': 'iel', 'suffix4': 'riel', 'suffix5': 'ariel', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'ari', 'prefix4': 'arie', 'prefix5': 'ariel'}
# {'suffix': 'e', 'suffix2': 'le', 'suffix3': 'tle', 'suffix4': 'otle', 'suffix5': 'totle', 'suffix6': 'stotle', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'ari', 'prefix4': 'aris', 'prefix5': 'arist'}
# {'suffix': 'o', 'suffix2': 'lo', 'suffix3': 'rlo', 'suffix4': 'arlo', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arl', 'prefix4': 'arlo', 'prefix5': 'a'}
# {'suffix': 'd', 'suffix2': 'nd', 'suffix3': 'and', 'suffix4': 'mand', 'suffix5': 'rmand', 'suffix6': 'armand', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arm', 'prefix4': 'arma', 'prefix5': 'arman'}
# {'suffix': 'o', 'suffix2': 'do', 'suffix3': 'ndo', 'suffix4': 'ando', 'suffix5': 'mando', 'suffix6': 'rmando', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arm', 'prefix4': 'arma', 'prefix5': 'arman'}
# {'suffix': 'd', 'suffix2': 'nd', 'suffix3': 'ond', 'suffix4': 'mond', 'suffix5': 'rmond', 'suffix6': 'armond', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arm', 'prefix4': 'armo', 'prefix5': 'armon'}
# {'suffix': 'g', 'suffix2': 'ng', 'suffix3': 'ong', 'suffix4': 'rong', 'suffix5': 'trong', 'suffix6': 'strong', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arm', 'prefix4': 'arms', 'prefix5': 'armst'}
# {'suffix': 'e', 'suffix2': 'ne', 'suffix3': 'rne', 'suffix4': 'arne', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arn', 'prefix4': 'arne', 'prefix5': 'a'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'nie', 'suffix4': 'rnie', 'suffix5': 'arnie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arn', 'prefix4': 'arni', 'prefix5': 'arnie'}
# {'suffix': 'd', 'suffix2': 'ld', 'suffix3': 'old', 'suffix4': 'nold', 'suffix5': 'rnold', 'suffix6': 'arnold', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arn', 'prefix4': 'arno', 'prefix5': 'arnol'}
# {'suffix': 'o', 'suffix2': 'do', 'suffix3': 'ldo', 'suffix4': 'oldo', 'suffix5': 'noldo', 'suffix6': 'rnoldo', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arn', 'prefix4': 'arno', 'prefix5': 'arnol'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ron', 'suffix4': 'aron', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'aro', 'prefix4': 'aron', 'prefix5': 'a'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ron', 'suffix4': 'rron', 'suffix5': 'arron', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arr', 'prefix4': 'arro', 'prefix5': 'arron'}
# {'suffix': 't', 'suffix2': 'rt', 'suffix3': 'art', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'art', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'r', 'suffix2': 'er', 'suffix3': 'her', 'suffix4': 'ther', 'suffix5': 'rther', 'suffix6': 'arther', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'art', 'prefix4': 'arth', 'prefix5': 'arthe'}
# {'suffix': 'r', 'suffix2': 'ur', 'suffix3': 'hur', 'suffix4': 'thur', 'suffix5': 'rthur', 'suffix6': 'arthur', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'art', 'prefix4': 'arth', 'prefix5': 'arthu'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'tie', 'suffix4': 'rtie', 'suffix5': 'artie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'art', 'prefix4': 'arti', 'prefix5': 'artie'}
# {'suffix': 'r', 'suffix2': 'ur', 'suffix3': 'tur', 'suffix4': 'rtur', 'suffix5': 'artur', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'art', 'prefix4': 'artu', 'prefix5': 'artur'}
# {'suffix': 'o', 'suffix2': 'ro', 'suffix3': 'uro', 'suffix4': 'turo', 'suffix5': 'rturo', 'suffix6': 'arturo', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'art', 'prefix4': 'artu', 'prefix5': 'artur'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'vie', 'suffix4': 'rvie', 'suffix5': 'arvie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arv', 'prefix4': 'arvi', 'prefix5': 'arvie'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'vin', 'suffix4': 'rvin', 'suffix5': 'arvin', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arv', 'prefix4': 'arvi', 'prefix5': 'arvin'}
# {'suffix': 'd', 'suffix2': 'nd', 'suffix3': 'ind', 'suffix4': 'vind', 'suffix5': 'rvind', 'suffix6': 'arvind', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arv', 'prefix4': 'arvi', 'prefix5': 'arvin'}
# {'suffix': 'y', 'suffix2': 'vy', 'suffix3': 'rvy', 'suffix4': 'arvy', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ar', 'prefix3': 'arv', 'prefix4': 'arvy', 'prefix5': 'a'}
# {'suffix': 'h', 'suffix2': 'sh', 'suffix3': 'ash', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'as', 'prefix3': 'ash', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'y', 'suffix2': 'by', 'suffix3': 'hby', 'suffix4': 'shby', 'suffix5': 'ashby', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'as', 'prefix3': 'ash', 'prefix4': 'ashb', 'prefix5': 'ashby'}
# {'suffix': 'h', 'suffix2': 'sh', 'suffix3': 'ish', 'suffix4': 'hish', 'suffix5': 'shish', 'suffix6': 'ashish', 'prefix': 'a', 'prefix2': 'as', 'prefix3': 'ash', 'prefix4': 'ashi', 'prefix5': 'ashis'}
# {'suffix': 'y', 'suffix2': 'ey', 'suffix3': 'ley', 'suffix4': 'hley', 'suffix5': 'shley', 'suffix6': 'ashley', 'prefix': 'a', 'prefix2': 'as', 'prefix3': 'ash', 'prefix4': 'ashl', 'prefix5': 'ashle'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ton', 'suffix4': 'hton', 'suffix5': 'shton', 'suffix6': 'ashton', 'prefix': 'a', 'prefix2': 'as', 'prefix3': 'ash', 'prefix4': 'asht', 'prefix5': 'ashto'}
# {'suffix': 'b', 'suffix2': 'ub', 'suffix3': 'aub', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aub', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'e', 'suffix2': 'be', 'suffix3': 'ube', 'suffix4': 'aube', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aub', 'prefix4': 'aube', 'prefix5': 'a'}
# {'suffix': 't', 'suffix2': 'rt', 'suffix3': 'ert', 'suffix4': 'bert', 'suffix5': 'ubert', 'suffix6': 'aubert', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aub', 'prefix4': 'aube', 'prefix5': 'auber'}
# {'suffix': 'y', 'suffix2': 'ey', 'suffix3': 'rey', 'suffix4': 'brey', 'suffix5': 'ubrey', 'suffix6': 'aubrey', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aub', 'prefix4': 'aubr', 'prefix5': 'aubre'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'gie', 'suffix4': 'ugie', 'suffix5': 'augie', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aug', 'prefix4': 'augi', 'prefix5': 'augie'}
# {'suffix': 't', 'suffix2': 'st', 'suffix3': 'ust', 'suffix4': 'gust', 'suffix5': 'ugust', 'suffix6': 'august', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aug', 'prefix4': 'augu', 'prefix5': 'augus'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'tin', 'suffix4': 'stin', 'suffix5': 'ustin', 'suffix6': 'gustin', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aug', 'prefix4': 'augu', 'prefix5': 'augus'}
# {'suffix': 'e', 'suffix2': 'ne', 'suffix3': 'ine', 'suffix4': 'tine', 'suffix5': 'stine', 'suffix6': 'ustine', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aug', 'prefix4': 'augu', 'prefix5': 'augus'}
# {'suffix': 'o', 'suffix2': 'to', 'suffix3': 'sto', 'suffix4': 'usto', 'suffix5': 'gusto', 'suffix6': 'ugusto', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aug', 'prefix4': 'augu', 'prefix5': 'augus'}
# {'suffix': 's', 'suffix2': 'us', 'suffix3': 'tus', 'suffix4': 'stus', 'suffix5': 'ustus', 'suffix6': 'gustus', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aug', 'prefix4': 'augu', 'prefix5': 'augus'}
# {'suffix': 'n', 'suffix2': 'en', 'suffix3': 'ten', 'suffix4': 'sten', 'suffix5': 'usten', 'suffix6': 'austen', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aus', 'prefix4': 'aust', 'prefix5': 'auste'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'tin', 'suffix4': 'stin', 'suffix5': 'ustin', 'suffix6': 'austin', 'prefix': 'a', 'prefix2': 'au', 'prefix3': 'aus', 'prefix4': 'aust', 'prefix5': 'austi'}
# {'suffix': 'e', 'suffix2': 've', 'suffix3': 'ave', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'ave', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'l', 'suffix2': 'll', 'suffix3': 'ell', 'suffix4': 'rell', 'suffix5': 'erell', 'suffix6': 'verell', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'ave', 'prefix4': 'aver', 'prefix5': 'avere'}
# {'suffix': 'l', 'suffix2': 'il', 'suffix3': 'ril', 'suffix4': 'eril', 'suffix5': 'veril', 'suffix6': 'averil', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'ave', 'prefix4': 'aver', 'prefix5': 'averi'}
# {'suffix': 'l', 'suffix2': 'll', 'suffix3': 'ill', 'suffix4': 'rill', 'suffix5': 'erill', 'suffix6': 'verill', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'ave', 'prefix4': 'aver', 'prefix5': 'averi'}
# {'suffix': 'y', 'suffix2': 'ry', 'suffix3': 'ery', 'suffix4': 'very', 'suffix5': 'avery', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'ave', 'prefix4': 'aver', 'prefix5': 'avery'}
# {'suffix': 'i', 'suffix2': 'vi', 'suffix3': 'avi', 'suffix4': 'a', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'avi', 'prefix4': 'a', 'prefix5': 'a'}
# {'suffix': 'm', 'suffix2': 'am', 'suffix3': 'ham', 'suffix4': 'aham', 'suffix5': 'raham', 'suffix6': 'vraham', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'avr', 'prefix4': 'avra', 'prefix5': 'avrah'}
# {'suffix': 'm', 'suffix2': 'am', 'suffix3': 'ram', 'suffix4': 'vram', 'suffix5': 'avram', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'avr', 'prefix4': 'avra', 'prefix5': 'avram'}
# {'suffix': 'm', 'suffix2': 'om', 'suffix3': 'rom', 'suffix4': 'vrom', 'suffix5': 'avrom', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'av', 'prefix3': 'avr', 'prefix4': 'avro', 'prefix5': 'avrom'}
# {'suffix': 'l', 'suffix2': 'el', 'suffix3': 'xel', 'suffix4': 'axel', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'ax', 'prefix3': 'axe', 'prefix4': 'axel', 'prefix5': 'a'}
# {'suffix': 'r', 'suffix2': 'er', 'suffix3': 'mer', 'suffix4': 'lmer', 'suffix5': 'ylmer', 'suffix6': 'aylmer', 'prefix': 'a', 'prefix2': 'ay', 'prefix3': 'ayl', 'prefix4': 'aylm', 'prefix5': 'aylme'}
# {'suffix': 'z', 'suffix2': 'iz', 'suffix3': 'ziz', 'suffix4': 'aziz', 'suffix5': 'a', 'suffix6': 'a', 'prefix': 'a', 'prefix2': 'az', 'prefix3': 'azi', 'prefix4': 'aziz', 'prefix5': 'a'}
# {'suffix': 'y', 'suffix2': 'ey', 'suffix3': 'ley', 'suffix4': 'iley', 'suffix5': 'ailey', 'suffix6': 'bailey', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bai', 'prefix4': 'bail', 'prefix5': 'baile'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'lie', 'suffix4': 'ilie', 'suffix5': 'ailie', 'suffix6': 'bailie', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bai', 'prefix4': 'bail', 'prefix5': 'baili'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'lie', 'suffix4': 'llie', 'suffix5': 'illie', 'suffix6': 'aillie', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bai', 'prefix4': 'bail', 'prefix5': 'baill'}
# {'suffix': 'y', 'suffix2': 'ly', 'suffix3': 'ily', 'suffix4': 'aily', 'suffix5': 'baily', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bai', 'prefix4': 'bail', 'prefix5': 'baily'}
# {'suffix': 'd', 'suffix2': 'rd', 'suffix3': 'ird', 'suffix4': 'aird', 'suffix5': 'baird', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bai', 'prefix4': 'bair', 'prefix5': 'baird'}
# {'suffix': 'n', 'suffix2': 'in', 'suffix3': 'win', 'suffix4': 'dwin', 'suffix5': 'ldwin', 'suffix6': 'aldwin', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bal', 'prefix4': 'bald', 'prefix5': 'baldw'}
# {'suffix': 't', 'suffix2': 'ft', 'suffix3': 'oft', 'suffix4': 'roft', 'suffix5': 'croft', 'suffix6': 'ncroft', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'ban', 'prefix4': 'banc', 'prefix5': 'bancr'}
# {'suffix': 's', 'suffix2': 'as', 'suffix3': 'bas', 'suffix4': 'abas', 'suffix5': 'babas', 'suffix6': 'rbabas', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barb', 'prefix5': 'barba'}
# {'suffix': 'y', 'suffix2': 'ay', 'suffix3': 'lay', 'suffix4': 'clay', 'suffix5': 'rclay', 'suffix6': 'arclay', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barc', 'prefix5': 'barcl'}
# {'suffix': 'd', 'suffix2': 'rd', 'suffix3': 'ard', 'suffix4': 'bard', 'suffix5': 'b', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'bard', 'prefix5': 'b'}
# {'suffix': 'e', 'suffix2': 'de', 'suffix3': 'rde', 'suffix4': 'arde', 'suffix5': 'barde', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'bard', 'prefix5': 'barde'}
# {'suffix': 'n', 'suffix2': 'rn', 'suffix3': 'arn', 'suffix4': 'barn', 'suffix5': 'b', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'b'}
# {'suffix': 's', 'suffix2': 'as', 'suffix3': 'bas', 'suffix4': 'abas', 'suffix5': 'nabas', 'suffix6': 'rnabas', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barna'}
# {'suffix': 'e', 'suffix2': 'be', 'suffix3': 'abe', 'suffix4': 'nabe', 'suffix5': 'rnabe', 'suffix6': 'arnabe', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barna'}
# {'suffix': 'y', 'suffix2': 'by', 'suffix3': 'aby', 'suffix4': 'naby', 'suffix5': 'rnaby', 'suffix6': 'arnaby', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barna'}
# {'suffix': 'd', 'suffix2': 'rd', 'suffix3': 'ard', 'suffix4': 'nard', 'suffix5': 'rnard', 'suffix6': 'arnard', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barna'}
# {'suffix': 's', 'suffix2': 'as', 'suffix3': 'bas', 'suffix4': 'ebas', 'suffix5': 'nebas', 'suffix6': 'rnebas', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barne'}
# {'suffix': 't', 'suffix2': 'tt', 'suffix3': 'ett', 'suffix4': 'nett', 'suffix5': 'rnett', 'suffix6': 'arnett', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barne'}
# {'suffix': 'y', 'suffix2': 'ey', 'suffix3': 'ney', 'suffix4': 'rney', 'suffix5': 'arney', 'suffix6': 'barney', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barne'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'nie', 'suffix4': 'rnie', 'suffix5': 'arnie', 'suffix6': 'barnie', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barni'}
# {'suffix': 'y', 'suffix2': 'ny', 'suffix3': 'rny', 'suffix4': 'arny', 'suffix5': 'barny', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barn', 'prefix5': 'barny'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ron', 'suffix4': 'aron', 'suffix5': 'baron', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'baro', 'prefix5': 'baron'}
# {'suffix': 'r', 'suffix2': 'rr', 'suffix3': 'arr', 'suffix4': 'barr', 'suffix5': 'b', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'b'}
# {'suffix': 't', 'suffix2': 'et', 'suffix3': 'ret', 'suffix4': 'rret', 'suffix5': 'arret', 'suffix6': 'barret', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'barre'}
# {'suffix': 't', 'suffix2': 'tt', 'suffix3': 'ett', 'suffix4': 'rett', 'suffix5': 'rrett', 'suffix6': 'arrett', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'barre'}
# {'suffix': 'i', 'suffix2': 'ri', 'suffix3': 'rri', 'suffix4': 'arri', 'suffix5': 'barri', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'barri'}
# {'suffix': 'e', 'suffix2': 'ie', 'suffix3': 'rie', 'suffix4': 'rrie', 'suffix5': 'arrie', 'suffix6': 'barrie', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'barri'}
# {'suffix': 's', 'suffix2': 'is', 'suffix3': 'ris', 'suffix4': 'rris', 'suffix5': 'arris', 'suffix6': 'barris', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'barri'}
# {'suffix': 'n', 'suffix2': 'on', 'suffix3': 'ron', 'suffix4': 'rron', 'suffix5': 'arron', 'suffix6': 'barron', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'barro'}
# {'suffix': 'y', 'suffix2': 'ry', 'suffix3': 'rry', 'suffix4': 'arry', 'suffix5': 'barry', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'barr', 'prefix5': 'barry'}
# {'suffix': 't', 'suffix2': 'rt', 'suffix3': 'art', 'suffix4': 'bart', 'suffix5': 'b', 'suffix6': 'b', 'prefix': 'b', 'prefix2': 'ba', 'prefix3': 'bar', 'prefix4': 'bart', 'prefix5': 'b'}
# ...
#  {'name': 'Ozzie', 'label': 'male'},
#  {'name': 'Partha', 'label': 'male'},
#  {'name': 'Pattie', 'label': 'male'},
#  {'name': 'Pennie', 'label': 'male'},
#  {'name': 'Pete', 'label': 'male'},
#  {'name': 'Randi', 'label': 'male'},
#  {'name': 'Rene', 'label': 'male'},
#  {'name': 'Rikki', 'label': 'male'},
#  {'name': 'Roni', 'label': 'male'},
#  {'name': 'Ronnie', 'label': 'male'},
#  {'name': 'Ronny', 'label': 'male'},
#  {'name': 'Ruby', 'label': 'male'},
#  {'name': 'Sascha', 'label': 'male'},
#  {'name': 'Sasha', 'label': 'male'},
#  {'name': 'Saundra', 'label': 'male'},
#  {'name': 'Shaine', 'label': 'male'},
#  {'name': 'Shane', 'label': 'male'},
#  {'name': 'Shay', 'label': 'male'},
#  {'name': 'Shayne', 'label': 'male'},
#  {'name': 'Shea', 'label': 'male'},
#  {'name': 'Sheridan', 'label': 'male'},
#  {'name': 'Sibyl', 'label': 'male'},
#  {'name': 'Siddhartha', 'label': 'male'},
#  {'name': 'Simone', 'label': 'male'},
#  {'name': 'Sonnie', 'label': 'male'},
#  {'name': 'Tabbie', 'label': 'male'},
#  {'name': 'Tallie', 'label': 'male'},
#  {'name': 'Tally', 'label': 'male'},
#  {'name': 'Tammie', 'label': 'male'},
#  {'name': 'Tammy', 'label': 'male'},
#  {'name': 'Tate', 'label': 'male'},
#  {'name': 'Terri', 'label': 'male'},
#  {'name': 'Timmie', 'label': 'male'},
#  {'name': 'Tracey', 'label': 'male'},
#  {'name': 'Tracie', 'label': 'male'},
#  {'name': 'Valentine', 'label': 'male'},
#  {'name': 'Vinnie', 'label': 'male'},
#  {'name': 'Vinny', 'label': 'male'},
#  {'name': 'Virge', 'label': 'male'},
#  {'name': 'Virgie', 'label': 'male'},
#  {'name': 'Vite', 'label': 'male'},
#  {'name': 'Voltaire', 'label': 'male'},
#  {'name': 'Winnie', 'label': 'male'},
#  {'name': 'Zacharia', 'label': 'male'},
#  {'name': 'Abbey', 'label': 'female'},
#  {'name': 'Adrian', 'label': 'female'},
#  {'name': 'Ag', 'label': 'female'},
#  {'name': 'Agace', 'label': 'female'},
#  {'name': 'Ajay', 'label': 'female'},
#  {'name': 'Alfie', 'label': 'female'},
#  {'name': 'Allsun', 'label': 'female'},
#  {'name': 'Amber', 'label': 'female'},
#  {'name': 'Ambur', 'label': 'female'},
#  {'name': 'Ariel', 'label': 'female'},
#  {'name': 'Ashleigh', 'label': 'female'},
#  {'name': 'Aubrey', 'label': 'female'},
#  {'name': 'Austin', 'label': 'female'},
#  {'name': 'Averil', 'label': 'female'},
#  {'name': 'Avis', 'label': 'female'},
#  {'name': 'Bab', 'label': 'female'},
#  {'name': 'Barrie', 'label': 'female'},
#  {'name': 'Barry', 'label': 'female'},
#  {'name': 'Beatriz', 'label': 'female'},
#  {'name': 'Beau', 'label': 'female'},
#  {'name': 'Benny', 'label': 'female'},
#  {'name': 'Beret', 'label': 'female'},
#  {'name': 'Bernie', 'label': 'female'},
#  {'name': 'Bert', 'label': 'female'},
#  {'name': 'Bev', 'label': 'female'},
#  {'name': 'Bill', 'label': 'female'},
#  {'name': 'Billy', 'label': 'female'},
#  {'name': 'Bird', 'label': 'female'},
#  {'name': 'Blair', 'label': 'female'},
#  {'name': 'Bo', 'label': 'female'},
#  {'name': 'Bren', 'label': 'female'},
#  {'name': 'Brenn', 'label': 'female'},
#  {'name': 'Brett', 'label': 'female'},
#  {'name': 'Brook', 'label': 'female'},
#  {'name': 'Brooke', 'label': 'female'},
#  {'name': 'Brooks', 'label': 'female'},
#  {'name': 'Bryn', 'label': 'female'},
#  {'name': 'Buffy', 'label': 'female'},
#  {'name': 'Cal', 'label': 'female'},
#  {'name': 'Calypso', 'label': 'female'},
#  {'name': 'Cam', 'label': 'female'},
#  {'name': 'Cecil', 'label': 'female'},
#  {'name': 'Ceil', 'label': 'female'},
#  {'name': 'Chad', 'label': 'female'},
#  {'name': 'Chandal', 'label': 'female'},
#  {'name': 'Charmain', 'label': 'female'},
#  {'name': 'Cher', 'label': 'female'},
#  {'name': 'Christan', 'label': 'female'},
#  {'name': 'Christian', 'label': 'female'},
#  {'name': 'Cinnamon', 'label': 'female'},
#  {'name': 'Clair', 'label': 'female'},
#  {'name': 'Clem', 'label': 'female'},
#  {'name': 'Clemmy', 'label': 'female'},
#  {'name': 'Cleo', 'label': 'female'},
#  {'name': 'Clio', 'label': 'female'},
#  {'name': 'Clo', 'label': 'female'},
#  {'name': 'Con', 'label': 'female'},
#  {'name': 'Daffy', 'label': 'female'},
#  {'name': 'Dagmar', 'label': 'female'},
#  {'name': 'Dallas', 'label': 'female'},
#  {'name': 'Daniel', 'label': 'female'},
#  {'name': 'Danit', 'label': 'female'},
#  {'name': 'Danny', 'label': 'female'},
#  {'name': 'Darby', 'label': 'female'},
#  {'name': 'Darell', 'label': 'female'},
#  {'name': 'Darryl', 'label': 'female'},
#  {'name': 'Daryl', 'label': 'female'},
#  {'name': 'Demeter', 'label': 'female'},
#  {'name': 'Demetris', 'label': 'female'},
#  {'name': 'Devin', 'label': 'female'},
#  {'name': 'Devon', 'label': 'female'},
#  {'name': 'Dew', 'label': 'female'},
#  {'name': 'Dido', 'label': 'female'},
#  {'name': 'Dion', 'label': 'female'},
#  {'name': 'Dionis', 'label': 'female'},
#  {'name': 'Dorcas', 'label': 'female'},
#  {'name': 'Drew', 'label': 'female'},
#  {'name': 'Dusty', 'label': 'female'},
#  {'name': 'Easter', 'label': 'female'},
#  {'name': 'Eddie', 'label': 'female'},
#  {'name': 'Eddy', 'label': 'female'},
#  {'name': 'Edin', 'label': 'female'},
#  {'name': 'Em', 'label': 'female'},
#  {'name': 'Emmy', 'label': 'female'},
#  {'name': 'Enid', 'label': 'female'},
#  {'name': 'Eran', 'label': 'female'},
#  {'name': 'Esme', 'label': 'female'},
#  {'name': 'Ester', 'label': 'female'},
#  {'name': 'Faith', 'label': 'female'},
#  {'name': 'Farrand', 'label': 'female'},
#  {'name': 'Felicdad', 'label': 'female'},
#  {'name': 'Felice', 'label': 'female'},
#  {'name': 'Felicle', 'label': 'female'},
#  {'name': 'Fern', 'label': 'female'},
#  {'name': 'Ferne', 'label': 'female'},
#  {'name': 'Fleur', 'label': 'female'},
#  {'name': 'Flor', 'label': 'female'},
#  {'name': 'Fran', 'label': 'female'},
#  {'name': 'France', 'label': 'female'},
#  {'name': 'Frances', 'label': 'female'},
#  {'name': 'Francis', 'label': 'female'},
#  {'name': 'Frank', 'label': 'female'},
#  {'name': 'Frankie', 'label': 'female'},
#  {'name': 'Franky', 'label': 'female'},
#  {'name': 'Fred', 'label': 'female'},
#  {'name': 'Freddie', 'label': 'female'},
#  {'name': 'Freddy', 'label': 'female'},
#  {'name': 'Friederike', 'label': 'female'},
#  {'name': 'Gabriel', 'label': 'female'},
#  {'name': 'Gabriell', 'label': 'female'},
#  {'name': 'Gaby', 'label': 'female'},
#  {'name': 'Gael', 'label': 'female'},
#  {'name': 'Gail', 'label': 'female'},
#  {'name': 'Gale', 'label': 'female'},
#  {'name': 'Garland', 'label': 'female'},
#  {'name': 'Gates', 'label': 'female'},
#  {'name': 'Gay', 'label': 'female'},
#  {'name': 'Gaynor', 'label': 'female'},
#  {'name': 'Gen', 'label': 'female'},
#  {'name': 'George', 'label': 'female'},
#  {'name': 'Germain', 'label': 'female'},
#  {'name': 'Gerry', 'label': 'female'},
#  {'name': 'Gert', 'label': 'female'},
#  {'name': 'Gill', 'label': 'female'},
#  {'name': 'Gillan', 'label': 'female'},
#  {'name': 'Ginger', 'label': 'female'},
#  {'name': 'Glynnis', 'label': 'female'},
#  {'name': 'Greer', 'label': 'female'},
#  {'name': 'Gretchen', 'label': 'female'},
#  {'name': 'Grier', 'label': 'female'},
#  {'name': 'Grissel', 'label': 'female'},
#  {'name': 'Gunvor', 'label': 'female'},
#  {'name': 'Gus', 'label': 'female'},
#  {'name': 'Haily', 'label': 'female'},
#  {'name': 'Haleigh', 'label': 'female'},
#  {'name': 'Haley', 'label': 'female'},
#  {'name': 'Halley', 'label': 'female'},
#  {'name': 'Hally', 'label': 'female'},
#  {'name': 'Hannibal', 'label': 'female'},
#  {'name': 'Hannis', 'label': 'female'},
#  {'name': 'Hanny', 'label': 'female'},
#  {'name': 'Harley', 'label': 'female'},
#  {'name': 'Harmony', 'label': 'female'},
#  {'name': 'Harriett', 'label': 'female'},
#  {'name': 'Harriot', 'label': 'female'},
#  {'name': 'Harriott', 'label': 'female'},
#  {'name': 'Hazel', 'label': 'female'},
#  {'name': 'Heather', 'label': 'female'},
#  {'name': 'Henrie', 'label': 'female'},
#  {'name': 'Hester', 'label': 'female'},
#  {'name': 'Hesther', 'label': 'female'},
#  {'name': 'Hilary', 'label': 'female'},
#  {'name': 'Hildagard', 'label': 'female'},
#  {'name': 'Hildegaard', 'label': 'female'},
#  {'name': 'Hillary', 'label': 'female'},
#  {'name': 'Hilliary', 'label': 'female'},
#  {'name': 'Hope', 'label': 'female'},
#  {'name': 'Ike', 'label': 'female'},
#  {'name': 'Ikey', 'label': 'female'},
#  {'name': 'Ingaborg', 'label': 'female'},
#  {'name': 'Inger', 'label': 'female'},
#  {'name': 'Iris', 'label': 'female'},
#  {'name': 'Isador', 'label': 'female'},
#  {'name': 'Izabel', 'label': 'female'},
#  {'name': 'Jamie', 'label': 'female'},
#  {'name': 'Jammie', 'label': 'female'},
#  {'name': 'Jan', 'label': 'female'},
#  {'name': 'Jean', 'label': 'female'},
#  {'name': 'Jemmy', 'label': 'female'},
#  {'name': 'Jen', 'label': 'female'},
#  {'name': 'Jere', 'label': 'female'},
#  {'name': 'Jerry', 'label': 'female'},
#  {'name': 'Jess', 'label': 'female'},
#  {'name': 'Jo', 'label': 'female'},
#  {'name': 'Jo Ann', 'label': 'female'},
#  {'name': 'Joey', 'label': 'female'},
#  {'name': 'Jordan', 'label': 'female'},
#  {'name': 'Josi', 'label': 'female'},
#  {'name': 'Joy', 'label': 'female'},
#  {'name': 'Judy', 'label': 'female'},
#  {'name': 'Justin', 'label': 'female'},
#  {'name': 'Kaster', 'label': 'female'},
#  {'name': 'Kiley', 'label': 'female'},
#  {'name': 'Leiah', 'label': 'female'},
#  {'name': 'Leigh', 'label': 'female'},
#  {'name': 'Leigha', 'label': 'female'},
#  {'name': 'Leland', 'label': 'female'},
#  {'name': 'Lesley', 'label': 'female'},
#  {'name': 'Lou', 'label': 'female'},
#  {'name': 'Maddie', 'label': 'female'},
#  {'name': 'Maddy', 'label': 'female'},
#  {'name': 'Maegan', 'label': 'female'},
#  {'name': 'Mair', 'label': 'female'},
#  {'name': 'Marian', 'label': 'female'},
#  {'name': 'Marigold', 'label': 'female'},
#  {'name': 'Marion', 'label': 'female'},
#  {'name': 'Marlo', 'label': 'female'},
#  {'name': 'Mattie', 'label': 'female'},
#  {'name': 'Maud', 'label': 'female'},
#  {'name': 'Mead', 'label': 'female'},
#  {'name': 'Mercedes', 'label': 'female'},
#  {'name': 'Meredith', 'label': 'female'},
#  {'name': 'Merrill', 'label': 'female'},
#  {'name': 'Michal', 'label': 'female'},
#  {'name': 'Micky', 'label': 'female'},
#  {'name': 'Mildred', 'label': 'female'},
#  {'name': 'Mildrid', 'label': 'female'},
#  {'name': 'Morgan', 'label': 'female'},
#  {'name': 'Morgen', 'label': 'female'},
#  {'name': 'Muffin', 'label': 'female'},
#  {'name': 'Mureil', 'label': 'female'},
#  {'name': 'Nat', 'label': 'female'},
#  {'name': 'Neely', 'label': 'female'},
#  {'name': 'Nert', 'label': 'female'},
#  {'name': 'Nichole', 'label': 'female'},
#  {'name': 'Nickie', 'label': 'female'},
#  {'name': 'Nicky', 'label': 'female'},
#  {'name': 'Niki', 'label': 'female'},
#  {'name': 'Nikki', 'label': 'female'},
#  {'name': 'Nil', 'label': 'female'},
#  {'name': 'Noel', 'label': 'female'},
#  {'name': 'Olive', 'label': 'female'},
#  {'name': 'Olly', 'label': 'female'},
#  {'name': 'Orel', 'label': 'female'},
#  {'name': 'Orly', 'label': 'female'},
#  {'name': 'Page', 'label': 'female'},
#  {'name': 'Paige', 'label': 'female'},
#  {'name': 'Pam', 'label': 'female'},
#  {'name': 'Pat', 'label': 'female'},
#  {'name': 'Patience', 'label': 'female'},
#  {'name': 'Patrice', 'label': 'female'},
#  {'name': 'Patsy', 'label': 'female'},
#  {'name': 'Patty', 'label': 'female'},
#  {'name': 'Peg', 'label': 'female'},
#  {'name': 'Pen', 'label': 'female'},
#  {'name': 'Penny', 'label': 'female'},
#  {'name': 'Pepi', 'label': 'female'},
#  {'name': 'Perry', 'label': 'female'},
#  {'name': 'Pet', 'label': 'female'},
#  {'name': 'Phil', 'label': 'female'},
#  {'name': 'Phillis', 'label': 'female'},
#  {'name': 'Pier', 'label': 'female'},
#  {'name': 'Piper', 'label': 'female'},
#  {'name': 'Pooh', 'label': 'female'},
#  {'name': 'Pris', 'label': 'female'},
#  {'name': 'Pru', 'label': 'female'},
#  {'name': 'Quentin', 'label': 'female'},
#  {'name': 'Quinn', 'label': 'female'},
#  {'name': 'Raf', 'label': 'female'},
#  {'name': 'Ragnhild', 'label': 'female'},
#  {'name': 'Rakel', 'label': 'female'},
#  {'name': 'Randie', 'label': 'female'},
#  {'name': 'Randy', 'label': 'female'},
#  {'name': 'Raven', 'label': 'female'},
#  {'name': 'Ray', 'label': 'female'},
#  {'name': 'Raynell', 'label': 'female'},
#  {'name': 'Rayshell', 'label': 'female'},
#  {'name': 'Regan', 'label': 'female'},
#  {'name': 'Reggie', 'label': 'female'},
#  {'name': 'Remy', 'label': 'female'},
#  {'name': 'Rey', 'label': 'female'},
#  {'name': 'Rici', 'label': 'female'},
#  {'name': 'Ricki', 'label': 'female'},
#  {'name': 'Rickie', 'label': 'female'},
#  {'name': 'Ricky', 'label': 'female'},
#  {'name': 'Robbie', 'label': 'female'},
#  {'name': 'Robbin', 'label': 'female'},
#  {'name': 'Robbyn', 'label': 'female'},
#  {'name': 'Robin', 'label': 'female'},
#  {'name': 'Roch', 'label': 'female'},
#  {'name': 'Romy', 'label': 'female'},
#  {'name': 'Rory', 'label': 'female'},
#  {'name': 'Ros', 'label': 'female'},
#  {'name': 'Row', 'label': 'female'},
#  {'name': 'Ryann', 'label': 'female'},
#  {'name': 'Sal', 'label': 'female'},
#  {'name': 'Salome', 'label': 'female'},
#  {'name': 'Sam', 'label': 'female'},
#  {'name': 'Sammy', 'label': 'female'},
#  {'name': 'Sandy', 'label': 'female'},
#  {'name': 'Sapphire', 'label': 'female'},
#  {'name': 'Sayre', 'label': 'female'},
#  {'name': 'Scarlet', 'label': 'female'},
#  {'name': 'Scarlett', 'label': 'female'},
#  {'name': 'Scotty', 'label': 'female'},
#  {'name': 'Sean', 'label': 'female'},
#  {'name': 'Shannon', 'label': 'female'},
#  {'name': 'Shaun', 'label': 'female'},
#  {'name': 'Shawn', 'label': 'female'},
#  {'name': 'Shel', 'label': 'female'},
#  {'name': 'Shelby', 'label': 'female'},
#  {'name': 'Shell', 'label': 'female'},
#  {'name': 'Shelley', 'label': 'female'},
#  {'name': 'Sher', 'label': 'female'},
#  {'name': 'Sib', 'label': 'female'},
#  {'name': 'Sigrid', 'label': 'female'},
#  {'name': 'Sileas', 'label': 'female'},
#  {'name': 'Sinead', 'label': 'female'},
#  {'name': 'Sonny', 'label': 'female'},
#  {'name': 'Stace', 'label': 'female'},
#  {'name': 'Stacy', 'label': 'female'},
#  {'name': 'Star', 'label': 'female'},
#  {'name': 'Starr', 'label': 'female'},
#  {'name': 'Stoddard', 'label': 'female'},
#  {'name': 'Sue', 'label': 'female'},
#  {'name': 'Sunny', 'label': 'female'},
#  {'name': 'Sydney', 'label': 'female'},
#  {'name': 'Tabby', 'label': 'female'},
#  {'name': 'Taffy', 'label': 'female'},
#  {'name': 'Talyah', 'label': 'female'},
#  {'name': 'Tamar', 'label': 'female'},
#  {'name': 'Ted', 'label': 'female'},
#  {'name': 'Teddie', 'label': 'female'},
#  {'name': 'Teddy', 'label': 'female'},
#  {'name': 'Terri-Jo', 'label': 'female'},
#  {'name': 'Terry', 'label': 'female'},
#  {'name': 'Tess', 'label': 'female'},
#  {'name': 'Theo', 'label': 'female'},
#  {'name': 'Thomasin', 'label': 'female'},
#  {'name': 'Tiff', 'label': 'female'},
#  {'name': 'Tim', 'label': 'female'},
#  {'name': 'Timmy', 'label': 'female'},
#  {'name': 'Tobe', 'label': 'female'},
#  {'name': 'Tobi', 'label': 'female'},
#  {'name': 'Tobie', 'label': 'female'},
#  {'name': 'Toby', 'label': 'female'},
#  {'name': 'Tomiko', 'label': 'female'},
#  {'name': 'Tommie', 'label': 'female'},
#  {'name': 'Tommy', 'label': 'female'},
#  {'name': 'Tony', 'label': 'female'},
#  {'name': 'Torey', 'label': 'female'},
#  {'name': 'Torrie', 'label': 'female'},
#  {'name': 'Tory', 'label': 'female'},
#  {'name': 'Trace', 'label': 'female'},
#  {'name': 'Tracy', 'label': 'female'},
#  {'name': 'Val', 'label': 'female'},
#  {'name': 'Vale', 'label': 'female'},
#  {'name': 'Valry', 'label': 'female'},
#  {'name': 'Van', 'label': 'female'},
#  {'name': 'Venus', 'label': 'female'},
#  {'name': 'Vin', 'label': 'female'},
#  {'name': 'Wallie', 'label': 'female'},
#  {'name': 'Wallis', 'label': 'female'},
#  {'name': 'Wally', 'label': 'female'},
#  {'name': 'Waly', 'label': 'female'},
#  {'name': 'Wandis', 'label': 'female'},
#  {'name': 'Wendy', 'label': 'female'},
#  {'name': 'Whitney', 'label': 'female'},
#  {'name': 'Willi', 'label': 'female'},
#  {'name': 'Willie', 'label': 'female'},
#  {'name': 'Willow', 'label': 'female'},
#  {'name': 'Willy', 'label': 'female'},
#  {'name': 'Willyt', 'label': 'female'},
#  {'name': 'Wilow', 'label': 'female'},
#  {'name': 'Windy', 'label': 'female'},
#  {'name': 'Wini', 'label': 'female'},
#  {'name': 'Winifred', 'label': 'female'},
#  {'name': 'Winnifred', 'label': 'female'},
#  {'name': 'Winny', 'label': 'female'},
#  {'name': 'Wren', 'label': 'female'},
#  {'name': 'Wynn', 'label': 'female'},
#  {'name': 'Wynnie', 'label': 'female'},
#  {'name': 'Wynny', 'label': 'female'},
#  {'name': 'Yoko', 'label': 'female'},
#  {'name': 'Zoe', 'label': 'female'}]

# %% [markdown]
# ## Question 9

# %%
# Store the model into joblib using dump method
# complete this
